# %% [markdown]
# * pivot() function is used to rotate/transpose the data from one column into mutiple columns and back using unpivot() method.
# * pivot() is an aggregation function
# * There is no unpivot() function available in pyspark.
# But we can use explode() and stack() method to acheive the reverse of pivot() in pyspark.

# %%
data = [("Banana",1000,"USA"), ("Carrots",1500,"USA"), ("Beans",1600,"USA"), \
      ("Orange",2000,"USA"),("Orange",2000,"USA"),("Banana",400,"China"), \
      ("Carrots",1200,"China"),("Beans",1500,"China"),("Orange",4000,"China"), \
      ("Banana",2000,"Canada"),("Carrots",2000,"Canada"),("Beans",2000,"Mexico")]

columns= ["Product","Amount","Country"]
df = spark.createDataFrame(data = data, schema = columns)
df.printSchema()
df.show(truncate=False)

# %%
df_pivot = df.groupBy("Country").pivot("Product").avg("Amount")
df_pivot.show()

# %%
# Problem - 
data_player = [("Virat Kohli",85,95,100), \
      ("Steve Smith",90,23, 51), \
      ("MS Dhoni",90,95,85)]

columns= ["Player","Match 1","Match 2","Match 3"]
df_player = spark.createDataFrame(data = data_player, schema = columns)
df_player.printSchema()
df_player.show(truncate=False)

# %%
df_player_unpivot = df_player.selectExpr("Player", "stack(3, 'Match 1', `Match 1`, 'Match 2', `Match 2`, 'Match 3', `Match 3`) as (Match, Score)")
df_player_unpivot.show()
