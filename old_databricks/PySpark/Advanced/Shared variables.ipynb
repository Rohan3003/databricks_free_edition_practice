# %% [markdown]
# ### Accumulator

# %%
# to create an accumulator
ac = spark.sparkContext.accumulator(0)

# %%
data = [1,2,3,4]
rdd = spark.sparkContext.parallelize(data)
rdd

# %%
accumulator_variable = sc.longAccumulator("ac_var")
accumulator_variable.add(1)

# %% [markdown]
# ### Broadcast
