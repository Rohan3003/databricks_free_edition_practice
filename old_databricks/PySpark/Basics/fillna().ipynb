# %%
data = [(1,'Rohan', 'Bangalore', 620451311), (2, 'Raj', 'Dallas', 13213213), (3, None, 'Pune', None)]
schema = ['id', 'name', 'city', 'contact_num']
df = spark.createDataFrame(data, schema)
df.show()

# %%
df_fillna  = df.fillna(value = 100000)
df_fillna.show()

# %%
df_fillna  = df.fillna(value = 'Sanjev')
df_fillna.show()
