# %%
json_path = 'dbfs:/databricks-datasets/definitive-guide/data/flight-data/json/2015-summary.json'
df = spark.read.format("json").load(json_path)
df.show(5)

# %%
df.createOrReplaceTempView('dfTable')

# %%
# selecting data using spark.sql
spark.sql("SELECT * FROM dfTable").show(2)

# %%
# %sql
SELECT * FROM dfTable LIMIT(2)

# %% [markdown]
# ### select()

# %% [markdown]
# ### selectExpr()
