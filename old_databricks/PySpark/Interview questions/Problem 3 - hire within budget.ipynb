# %% [markdown]
# Q) Hire the candidates who fall under budget of 70000 according to following criteria
#   1) First hire Senior within budget.
#   2) Then hire Junior within the remaining budget.

# %%
data = [
    (1,"Junior", 10000),
    (2,"Junior",15000),
    (3,"Junior",40000),
    (4,"Senior",16000),
    (5,"Senior",20000),
    (6,"Senior",50000)
]
columns = ["emp_id","experience","salary"]
df = spark.createDataFrame(data, columns)
df.show()
