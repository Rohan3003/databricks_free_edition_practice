# %%
from pyspark.sql.functions import rand

# %%
data = [
    (1,"ProductA","Category1","Brand","Supplier",,,"2023-0-0","2023-0-0",True),
    (2,"ProductB","Category","Brand","Supplier",,,"2023-0-0","2023-0-0",True),
    (3,"ProductC","Category","Brand","Supplier",,,"2023-0-0","2023-0-0",False),
    (4,"ProductD","Category","Brand","Supplier",,,"2023-0-0","2023-0-0",True),
    (5,"ProductE","Category","Brand","Supplier",,,"2023-0-0","2023-0-0",True),
]
