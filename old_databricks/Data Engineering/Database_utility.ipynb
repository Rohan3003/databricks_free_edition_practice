# %% [markdown]
# ### read from table

# %%
def read_table_query()

# %% [markdown]
# ### Execute query

# %%
def execute_query():
    """ to run any specific query to the database
    """
    return None

# %% [markdown]
# ### write to table
