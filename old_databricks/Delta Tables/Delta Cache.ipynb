# %% [markdown]
# https://www.youtube.com/watch?v=S5-sHGCgeUI&t=86s&ab_channel=Raja%27sDataEngineering

# %%
spark.conf.get("spark.databricks.io.cache.enabled")

# %%
spark.conf.set("spark.databricks.io.cache.enabled", "true")

# %%
spark.conf.get("spark.databricks.io.cache.enabled")
