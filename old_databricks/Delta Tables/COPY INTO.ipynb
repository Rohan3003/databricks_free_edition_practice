# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('dbfs:/temp/'))

# %%
path_to_delete = 'dbfs:/user/deltaTables'
dbutils.fs.rm(dir = path_to_delete, recurse = True)

# %%
dbutils.fs.rm(delta_table_path, recurse = True)

# %%
# Specify the directory path
print(delta_table_path)

# List the files and directories within the target directory
files_in_directory = dbutils.fs.ls(delta_table_path)

# Display the list of files and directories
for item in files_in_directory:
    print(item.path)

# %%
delta_table_path = 'dbfs:/temp/df_delta'
df = spark.read.format('delta').load(delta_table_path)
df.display()

# %%
# COPY INTO statement is used to directly load data from CSV, Parquet or any supportted format into your Delta table
delta_table_path = 'dbfs:/user/delta_table'

COPY INTO default.example
FROM delta_table_path
FORMAT_OPTIONS(
    'header' = 'true',
    'inferSchema' = 'true',
    'mergeSchema' = 'true'
)
COPY_OPTIONS('mergeSchema' = 'true')

# %%
spark.sql("""
   COPY INTO default.example
   FROM ''
          
"""
)
