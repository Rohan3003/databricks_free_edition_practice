# %%
def func_calculate_sum(number) -> int:
    sum = 0 
    for i in range(len(number)):
        sum = i + sum
    return sum

# %%
list_1 = [1,2,3]
func_calculate_sum(list_1)

# %%
import pathlib
help(pathlib)
