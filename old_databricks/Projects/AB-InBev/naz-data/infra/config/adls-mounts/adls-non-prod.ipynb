# %%
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope="naz-data-kv", key="spn-client-id"),
    "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope="naz-data-kv", key="spn-client-key"),
    "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/cef04b19-7776-4a94-b89b-375c77a8f936/oauth2/token",
}

dbutils.fs.mount(
    source="abfss://internal@nazbtecheu2nraw.dfs.core.windows.net",
    mount_point="/mnt/raw-internal",
    extra_configs=configs,
)
dbutils.fs.mount(
    source="abfss://external@nazbtecheu2nraw.dfs.core.windows.net",
    mount_point="/mnt/raw-external",
    extra_configs=configs,
)
