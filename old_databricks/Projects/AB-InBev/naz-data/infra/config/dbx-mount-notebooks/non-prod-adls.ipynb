# %%
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope="alchemy-kv", key="overwatch-client-id"),
    "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope="alchemy-kv", key="overwatch-client-key"),
    "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/cef04b19-7776-4a94-b89b-375c77a8f936/oauth2/token",
}

dbutils.fs.mount(
    source="abfss://cluster-logs-naz-data@nazbtecheu2pclusterlogs.dfs.core.windows.net",
    mount_point="/mnt/cluster-logs-naz-data",
    extra_configs=configs,
)
