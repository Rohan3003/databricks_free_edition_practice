# %%
dbutils.notebook.run("/Workspace/Users/rohanwatson44@gmail.com/DataEngineering/dataframes", timeout_seconds = 60)

# %%
df_master.show(5)

# %%
df_cache = df_master.cache()

# %%
# %run 
/Workspace/Users/rohanwatson44@gmail.com/DataEngineering/dataframes

# %%
df_master.show(5)

# %%
df_cache = df_master.cache()

# %%
# to check time difference with and without cache
start_time = time.time()
df_cache_1 = df_cache.distinct.count()

# %%
start_time = time.time()

# Add caching to the unique rows in departures_df
departures_df = departures_df.distinct().cache()

# Count the unique rows in departures_df, noting how long the operation takes
print("Counting %d rows took %f seconds" % (departures_df.count(), time.time() - start_time))

# Count the rows again, noting the variance in time of a cached DataFrame
start_time = time.time()
print("Counting %d rows again took %f seconds" % (departures_df.count(), time.time() - start_time))

# %%
from pyspark.sql.

# %%
print(f"To check if the dataframe is cached or not ? : {df_cache.is_cached}")
